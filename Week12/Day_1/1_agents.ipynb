# %% [markdown]
# # Install and Import phidata
# Install the phidata library and import necessary modules for working with agents, tools, knowledge, and storage components.

# %%
! pip install numpy==1.26.4 ipykernel phidata openai ipywidgets duckduckgo-search yfinance crawl4ai lancedb sentence-transformers torch pypdf chromadb duckdb
# Out:
# Requirement already satisfied: numpy==1.26.4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (1.26.4)
# Requirement already satisfied: ipykernel in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (7.1.0)
# Requirement already satisfied: phidata in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (2.7.10)
# Requirement already satisfied: openai in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (2.14.0)
# Requirement already satisfied: ipywidgets in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (8.1.8)
# Requirement already satisfied: duckduckgo-search in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (8.1.1)
# Requirement already satisfied: yfinance in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (0.2.66)
# Requirement already satisfied: crawl4ai in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (0.7.8)
# Requirement already satisfied: lancedb in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (0.26.0)
# Requirement already satisfied: sentence-transformers in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (5.2.0)
# Requirement already satisfied: torch in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (2.9.1)
# Requirement already satisfied: pypdf in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (6.4.2)
# Requirement already satisfied: chromadb in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (1.3.7)
# Requirement already satisfied: duckdb in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (1.4.3)
# Requirement already satisfied: appnope>=0.1.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (1.8.19)
# Requirement already satisfied: ipython>=7.23.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (9.8.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (8.7.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (6.5.4)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: docstring-parser in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (0.17.0)
# Requirement already satisfied: gitpython in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (3.1.45)
# Requirement already satisfied: httpx in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (0.28.1)
# Requirement already satisfied: pydantic in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (2.12.5)
# Requirement already satisfied: pydantic-settings in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (2.12.0)
# Requirement already satisfied: python-dotenv in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (1.2.1)
# Requirement already satisfied: pyyaml in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (6.0.3)
# Requirement already satisfied: rich in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (14.2.0)
# Requirement already satisfied: tomli in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (2.3.0)
# Requirement already satisfied: typer in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (0.20.1)
# Requirement already satisfied: typing-extensions in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from phidata) (4.15.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from openai) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from openai) (0.12.0)
# Requirement already satisfied: sniffio in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: idna>=2.8 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from httpx->phidata) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from httpx->phidata) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx->phidata) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from pydantic->phidata) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from pydantic->phidata) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from pydantic->phidata) (0.4.2)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: click>=8.1.8 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from duckduckgo-search) (8.3.1)
# Requirement already satisfied: primp>=0.15.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from duckduckgo-search) (0.15.0)
# Requirement already satisfied: lxml>=5.3.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from duckduckgo-search) (5.4.0)
# Requirement already satisfied: pandas>=1.3.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: requests>=2.31 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi>=0.7 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (0.14.0)
# Requirement already satisfied: protobuf>=3.19.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (25.1.0)
# Requirement already satisfied: aiohttp>=3.11.11 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (3.13.2)
# Requirement already satisfied: aiosqlite~=0.20 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (0.22.0)
# Requirement already satisfied: litellm>=1.53.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (1.80.10)
# Requirement already satisfied: pillow>=10.4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (12.0.0)
# Requirement already satisfied: playwright>=1.49.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (1.57.0)
# Requirement already satisfied: patchright>=1.49.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (1.56.0)
# Requirement already satisfied: tf-playwright-stealth>=1.1.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (1.2.0)
# Requirement already satisfied: xxhash~=3.4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (3.6.0)
# Requirement already satisfied: rank-bm25~=0.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (0.2.2)
# Requirement already satisfied: snowballstemmer~=2.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (2.2.0)
# Requirement already satisfied: pyOpenSSL>=25.3.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (25.3.0)
# Requirement already satisfied: nltk>=3.9.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (3.9.2)
# Requirement already satisfied: cssselect>=1.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (1.3.0)
# Requirement already satisfied: fake-useragent>=2.0.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (2.2.0)
# Requirement already satisfied: chardet>=5.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (5.2.0)
# Requirement already satisfied: brotli>=1.1.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (1.2.0)
# Requirement already satisfied: humanize>=4.10.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (4.14.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (1.3.1)
# Requirement already satisfied: alphashape>=1.3.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (1.3.1)
# Requirement already satisfied: shapely>=2.0.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from crawl4ai) (2.1.2)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: deprecation in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from lancedb) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from lancedb) (22.0.0)
# Requirement already satisfied: lance-namespace>=0.3.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from lancedb) (0.3.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: scikit-learn in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: filelock in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: setuptools in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: build>=1.0.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.38.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: pypika>=0.48.9 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: overrides>=7.3.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (1.67.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (3.11.5)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from aiohttp>=3.11.11->crawl4ai) (1.22.0)
# Requirement already satisfied: click-log>=0.3.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from alphashape>=1.3.1->crawl4ai) (0.4.0)
# Requirement already satisfied: trimesh>=3.9.8 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from alphashape>=1.3.1->crawl4ai) (4.10.1)
# Requirement already satisfied: rtree>=0.9.7 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from alphashape>=1.3.1->crawl4ai) (1.4.1)
# Requirement already satisfied: pyproject_hooks in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: cffi>=1.12.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: pycparser in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: h2<5,>=3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from httpx[http2]>=0.27.2->crawl4ai) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from h2<5,>=3->httpx[http2]>=0.27.2->crawl4ai) (4.1.0)
# Requirement already satisfied: decorator>=4.3.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: lance-namespace-urllib3-client==0.3.2 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from lance-namespace>=0.3.2->lancedb) (0.3.2)
# Requirement already satisfied: fastuuid>=0.13.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from litellm>=1.53.1->crawl4ai) (0.14.0)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from litellm>=1.53.1->crawl4ai) (8.7.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from litellm>=1.53.1->crawl4ai) (0.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: zipp>=3.20 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from importlib-metadata>=6.8.0->litellm>=1.53.1->crawl4ai) (3.23.0)
# Requirement already satisfied: joblib in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from nltk>=3.9.1->crawl4ai) (1.5.3)
# Requirement already satisfied: coloredlogs in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: pyee<14,>=13 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from patchright>=1.49.0->crawl4ai) (13.0.0)
# Requirement already satisfied: greenlet<4.0.0,>=3.1.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from patchright>=1.49.0->crawl4ai) (3.3.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel) (0.7.0)
# Requirement already satisfied: cryptography<47,>=45.0.7 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from pyOpenSSL>=25.3.0->crawl4ai) (46.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from rich->phidata) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->phidata) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: fake-http-header<0.4.0,>=0.3.5 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from tf-playwright-stealth>=1.1.0->crawl4ai) (0.3.5)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from typer->phidata) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: uvloop>=0.15.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.22.1)
# Requirement already satisfied: watchfiles>=0.13 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from gitpython->phidata) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython->phidata) (5.0.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week12/venv/lib/python3.13/site-packages (from scikit-learn->sentence-transformers) (3.6.0)

# %% [markdown]
# ### Explanation of the Code
#
# The code performs the following steps:
#
# 1. **Importing Required Modules**:
#     - `os`: Provides functions to interact with the operating system.
#     - `load_dotenv` from `dotenv`: Loads environment variables from a `.env` file into the system environment.
#
# 2. **Loading Environment Variables**:
#     - The `load_dotenv()` function is called to load environment variables from a `.env` file.
#
# 3. **Clearing Conflicting Environment Variables**:
#     - A list of environment variables (`env_vars_to_clear`) is defined, which includes `OPENAI_API_KEY`, `OPENAI_BASE_URL`, and `OPENAI_API_BASE`.
#     - For each variable in the list, the code checks if it exists in the environment. If it does, it prints a warning message and deletes the variable from the environment.
#
# 4. **Setting New Environment Variables**:
#     - The `OPENAI_API_KEY` is set to the value of the `OPEN_ROUTER_KEY` environment variable.
#     - Both `OPENAI_API_BASE` and `OPENAI_BASE_URL` are set to `'https://openrouter.ai/api/v1'`.
#
# 5. **Commented-Out Code**:
#     - There is an alternative block of code (commented out) that clears the same environment variables and sets `OPENAI_API_KEY` to the value of the `OPEN_AI_KEY` environment variable instead.
#
# ### Purpose:
# This code ensures that conflicting environment variables are removed and sets up the required environment variables for interacting with the OpenRouter API. It provides flexibility to switch between different API keys and base URLs by modifying the `.env` file or uncommenting the alternative block of code.

# %%
import os
from dotenv import load_dotenv

# Load environment variables from local .env
load_dotenv()

# Also load from Week10/.env where you have your keys
load_dotenv('/Users/arifshaikh/Documents/GitHub/GenAIEngineering-Cohort3/Week10/.env', override=True)

env_vars_to_clear = ['OPENAI_API_KEY', 'OPENAI_BASE_URL', 'OPENAI_API_BASE']
for var in env_vars_to_clear:
    if os.getenv(var):
        print(f"⚠️  Removing conflicting {var}")
        del os.environ[var]

# Set OpenRouter key
OPEN_ROUTER_KEY = os.getenv("OPEN_ROUTER_KEY")
if OPEN_ROUTER_KEY:
    os.environ["OPENAI_API_KEY"] = OPEN_ROUTER_KEY
    os.environ['OPENAI_API_BASE'] = 'https://openrouter.ai/api/v1'
    os.environ['OPENAI_BASE_URL'] = 'https://openrouter.ai/api/v1'
    print(f"✅ OpenRouter key loaded ({len(OPEN_ROUTER_KEY)} chars)")
else:
    print("❌ OPEN_ROUTER_KEY not found in .env file!")



# env_vars_to_clear = ['OPENAI_API_KEY', 'OPENAI_BASE_URL', 'OPENAI_API_BASE']
# for var in env_vars_to_clear:
#     if os.getenv(var):
#         print(f"⚠️  Removing conflicting {var}")
#         del os.environ[var]
# os.environ["OPENAI_API_KEY"] = os.getenv("OPEN_AI_KEY")
# Out:
# ⚠️  Removing conflicting OPENAI_API_KEY
# ✅ OpenRouter key loaded (73 chars)

# %% [markdown]
# ### Explanation of the Code
#
# The code in the next cell performs the following steps:
#
# 1. **Importing Required Modules**:
#     - `phi.agent.Agent`: Used to create an agent that can perform reasoning tasks.
#     - `phi.tools.Tool`: Provides tools that can be used by the agent.
#     - `phi.model.openai.OpenAIChat`: Represents the OpenAI GPT model used for generating responses.
#     - `phi.utils.pprint.pprint_run_response`: A utility function to pretty-print the agent's response.
#
# ### Purpose:
# This code sets up the necessary imports to create and interact with agents that utilize OpenAI's GPT models for reasoning and task execution. It also includes tools and utilities for enhancing the agent's functionality and formatting its output.

# %%
from phi.agent import Agent
from phi.tools import Tool
from phi.model.openai import OpenAIChat
from phi.utils.pprint import pprint_run_response

# %% [markdown]
# ### Explanation of the Code
#
# The code in the next cell performs the following steps:
#
# 1. **Defining the Task**:
#     - A variable `task` is defined, containing a classic river-crossing puzzle involving missionaries and cannibals. The task requires a step-by-step solution and an ASCII diagram representation.
#
# 2. **Creating a Reasoning Agent**:
#     - An instance of the `Agent` class is created with the following parameters:
#         - `model`: Specifies the OpenAI GPT model (`openai/gpt-4o`) to be used.
#         - `reasoning`: Enables reasoning capabilities for the agent.
#         - `markdown`: Ensures the output is formatted in Markdown.
#         - `structured_outputs`: Enables structured outputs for better organization of the response.
#
# 3. **Executing the Task**:
#     - The `print_response` method of the agent is called with the following parameters:
#         - `task`: The river-crossing puzzle defined earlier.
#         - `stream`: Enables streaming of the response.
#         - `show_full_reasoning`: Displays the full reasoning process of the agent.
#
# ### Purpose:
# This code sets up a reasoning agent to solve a logical puzzle. It demonstrates the agent's ability to reason through complex problems and present the solution in a structured and Markdown-formatted manner.

# %%
input = (
    "Three missionaries and three cannibals need to cross a river. "
    "They have a boat that can carry up to two people at a time. "
    "If, at any time, the cannibals outnumber the missionaries on either side of the river, the cannibals will eat the missionaries. "
    "How can all six people get across the river safely? Provide a step-by-step solution and show the solutions as an ascii diagram"
)

reasoning_agent = Agent(model=OpenAIChat(id="google/gemini-2.5-flash"), reasoning=True, markdown=True, structured_outputs=True)
reasoning_agent.print_response(input, stream=True, show_full_reasoning=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### Explanation of the Code
#
# The code in the next cell performs the following steps:
#
# 1. **Creating a New Agent**:
#     - A variable `agent` is defined as an instance of the `Agent` class.
#     - The agent is initialized with the following parameters:
#         - `model`: Specifies the OpenAI GPT model (`gpt-4o`) to be used.
#         - `instructions`: Provides specific instructions for the agent to operate in the "Indian context."
#
# 2. **Running the Agent**:
#     - The `run` method of the agent is called with the input `"Share a 2 sentence horror story"`.
#     - The agent processes the input and generates a response.
#
# 3. **Pretty-Printing the Response**:
#     - The `pprint_run_response` function is used to format and display the agent's response in Markdown format.
#
# ### Purpose:
# This code demonstrates how to create and configure an agent with specific instructions, run it with a given input, and display the response in a readable format.

# %%
agent = Agent(model=OpenAIChat(id="openai/gpt-4o"), instructions=["in indian context"])
# agent.print_response("Share a 2 sentence horror story", stream=True)

response=agent.run("Share a 2 sentence humorous story")
# print(response)

pprint_run_response(response, markdown=True)
# Out:
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Rahul, an ambitious fitness enthusiast, decided to try yoga for the first time, boasting to everyone he'd       │
# │ master the crow pose. Fifteen minutes later, he had to be rescued from an elaborate headstand that probably had │
# │ more in common with an origami swan than any yoga sequence ever documented.                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ### Explanation of the Code
#
# The code in the next cell performs the following steps:
#
# 1. **Running the Agent with a New Input**:
#     - The `agent.run()` method is called with the input `"Simulation theory"`.
#     - This method processes the input and generates a response based on the agent's configuration and reasoning capabilities.
#
# 2. **Streaming the Response**:
#     - The `stream=True` parameter ensures that the response is streamed in real-time as it is generated.
#
# 3. **Pretty-Printing the Response**:
#     - The `pprint_run_response()` function is used to format and display the streamed response in Markdown format.
#     - The `show_time=True` parameter includes timestamps in the output, providing additional context about when each part of the response was generated.
#
# ### Purpose:
# This code demonstrates how to use the agent to process a new input (`"Simulation theory"`) and display the response in a structured and readable format with timestamps. It highlights the agent's ability to handle dynamic inputs and provide real-time feedback.

# %%
# Run agent and return the response as a stream
response_stream = agent.run("Simulation theory", stream=True)
# Print the response stream in markdown format
pprint_run_response(response_stream, markdown=True, show_time=True)

print(type(response_stream))  # Should show it's a generator
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <class 'generator'>

# %% [markdown]
# ### Explanation of the Code
#
# The code in the next cell performs the following steps:
#
# 1. **Defining a Pydantic Model**:
#     - A `MovieScript` class is defined using Pydantic's `BaseModel`.
#     - This model enforces a structured format for movie scripts with the following fields:
#         - `setting`: Describes the setting of the movie.
#         - `ending`: Specifies the ending of the movie, defaulting to a happy ending if not provided.
#         - `genre`: Defines the genre of the movie, defaulting to action, thriller, or romantic comedy if not specified.
#         - `name`: Assigns a name to the movie.
#         - `characters`: Lists the names of the characters in the movie.
#         - `storyline`: Provides a 3-sentence storyline for the movie.
#
# 2. **Creating Agents**:
#     - Two agents are created using the `Agent` class:
#         - `json_mode_agent`: Configured to write movie scripts with a description of "You write movie scripts."
#         - `structured_output_agent`: Similar to `json_mode_agent` but intended for structured outputs (though this feature is commented out).
#
# 3. **Running the Agent**:
#     - The `json_mode_agent` is instructed to generate a movie script for "a love story" using the `print_response` method with streaming enabled.
#
# 4. **Commented-Out Code**:
#     - The `structured_output_agent` is also set up to generate a movie script for "New York," but this functionality is commented out.
#
# ### Purpose:
# This code demonstrates how to define a structured format for movie scripts using Pydantic and create agents capable of generating movie scripts based on specific inputs. It highlights the flexibility of the agents to work in JSON mode or structured output mode.

# %%
from typing import List
from pydantic import BaseModel, Field
from phi.agent import Agent
from phi.model.openai import OpenAIChat

# Define a Pydantic model to enforce the structure of the output
class MovieScript(BaseModel):
    setting: str = Field(..., description="Provide a nice setting for a blockbuster movie.")
    ending: str = Field(..., description="Ending of the movie. If not available, provide a happy ending.")
    genre: str = Field(..., description="Genre of the movie. If not available, select action, thriller or romantic comedy.")
    name: str = Field(..., description="Give a name to this movie")
    characters: List[str] = Field(..., description="Name of characters for this movie.")
    storyline: str = Field(..., description="3 sentence storyline for the movie. Make it exciting!")

# Agent that uses JSON mode
json_mode_agent = Agent(
    model=OpenAIChat(id="openai/gpt-4o"),
    description="You write movie scripts.",
    response_model=MovieScript,
    structured_outputs=True,
 
)
# json_mode_agent.print_response("a love story", stream=True)

json_output = json_mode_agent.run("a love story", stream=True)

# %%
print(type(json_output))
# Out:
# <class 'phi.run.response.RunResponse'>

# %%
json_output
# Out:
# RunResponse(content=MovieScript(setting='The bustling streets of Rome, where ancient history blends seamlessly with modern life.', ending='Amidst the vibrant celebration of a street festival, Leo and Isabella finally express their true feelings under the stars, dancing as fireworks light up the sky, sealing their love with a passionate kiss.', genre='Romantic Comedy', name='Love in the Eternal City', characters=['Leo Roberts', 'Isabella Ricci'], storyline="Leo Roberts, an uptight architect from New York, travels to Rome for a project and unexpectedly meets Isabella Ricci, a lively local tour guide. As they explore the city's hidden wonders together, Leo's rigid views on life are challenged by Isabella's free-spirited nature. Their playful banter turns into undeniable chemistry, forcing them to confront their hearts and the possibility of an unexpected romance."), content_type='MovieScript', event='RunResponse', messages=[Message(role='developer', content='You write movie scripts.', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1766241610), Message(role='user', content='a love story', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1766241610), Message(role='assistant', content='{"setting":"The bustling streets of Rome, where ancient history blends seamlessly with modern life.","ending":"Amidst the vibrant celebration of a street festival, Leo and Isabella finally express their true feelings under the stars, dancing as fireworks light up the sky, sealing their love with a passionate kiss.","genre":"Romantic Comedy","name":"Love in the Eternal City","characters":["Leo Roberts","Isabella Ricci"],"storyline":"Leo Roberts, an uptight architect from New York, travels to Rome for a project and unexpectedly meets Isabella Ricci, a lively local tour guide. As they explore the city\'s hidden wonders together, Leo\'s rigid views on life are challenged by Isabella\'s free-spirited nature. Their playful banter turns into undeniable chemistry, forcing them to confront their hearts and the possibility of an unexpected romance."}', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={'time': 3.8401562080252916, 'input_tokens': 196, 'prompt_tokens': 196, 'output_tokens': 167, 'completion_tokens': 167, 'total_tokens': 363, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'image_tokens': 0}}, references=None, created_at=1766241614)], metrics=defaultdict(<class 'list'>, {'time': [3.8401562080252916], 'input_tokens': [196], 'prompt_tokens': [196], 'output_tokens': [167], 'completion_tokens': [167], 'total_tokens': [363], 'prompt_tokens_details': [{'audio_tokens': 0, 'cached_tokens': 0, 'video_tokens': 0}], 'completion_tokens_details': [{'reasoning_tokens': 0, 'image_tokens': 0}]}), model='openai/gpt-4o', run_id='2a20d919-42e2-4dae-8e1f-1adc2dffe7d3', agent_id='ec42184e-e196-437a-bedd-c5a39f868c26', session_id='c0a2440b-6c72-4d68-8379-897b18375ba9', workflow_id=None, tools=None, images=None, videos=None, audio=None, response_audio=None, extra_data=None, created_at=1766241373)

# %%
# Agent that uses structured outputs
structured_output_agent = Agent(
    model=OpenAIChat(id="gpt-4o"),
    description="You write movie scripts.",
    response_model=MovieScript,
    structured_outputs=True,
)

structured_output_agent.print_response("New York", stream=True)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# from phi.agent import Agent
# from phi.model.openai import OpenAIChat
# from phi.storage.agent.sqlite import SqlAgentStorage
# from phi.tools.duckduckgo import DuckDuckGo
# from phi.tools.yfinance import YFinanceTools
# from phi.playground import Playground, serve_playground_app

# web_agent = Agent(
#     name="Web Agent",
#     model=OpenAIChat(id="gpt-4o"),
#     tools=[DuckDuckGo()],
#     instructions=["Always include sources"],
#     storage=SqlAgentStorage(table_name="web_agent", db_file="agents.db"),
#     add_history_to_messages=True,
#     markdown=True,
# )

# finance_agent = Agent(
#     name="Finance Agent",
#     model=OpenAIChat(id="gpt-4o"),
#     tools=[YFinanceTools(stock_price=True, analyst_recommendations=True, company_info=True, company_news=True)],
#     instructions=["Use tables to display data"],
#     storage=SqlAgentStorage(table_name="finance_agent", db_file="agents.db"),
#     add_history_to_messages=True,
#     markdown=True,
# )

# app = Playground(agents=[finance_agent, web_agent]).get_app()

# if __name__ == "__main__":
#     serve_playground_app("playground:app", reload=True)
